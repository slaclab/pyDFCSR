# %%
import sys
sys.path.insert(0,'../')
import numpy as np

from CSR import *
import matplotlib.pyplot as plt
from matplotlib import cm
import h5py
from tools import plot_surface

# %% [markdown]
# ## Run DFCSR

# %%
testCSR = CSR2D(input_file= 'input/dipole_config_fromfile.yaml')

# %%
testCSR.run()
# Out:
# Calculating CSR at s= 0.1
# --- 4.6126275062561035 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-wakes.h5
# Finish step 2 in 5.758716106414795 seconds
# Calculating CSR at s= 0.2
# --- 4.447563648223877 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-wakes.h5
# Finish step 3 in 5.166910886764526 seconds
# Calculating CSR at s= 0.30000000000000004
# --- 4.218015670776367 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-wakes.h5
# Finish step 4 in 4.95008111000061 seconds
# Calculating CSR at s= 0.4
# --- 4.263575553894043 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-wakes.h5
# Finish step 5 in 4.97285795211792 seconds
# Calculating CSR at s= 0.5
# --- 4.6917877197265625 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-wakes.h5
# Finish step 6 in 5.46866774559021 seconds
# Calculating CSR at s= 0.6
# --- 4.410527229309082 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-wakes.h5
# Finish step 7 in 5.206511735916138 seconds
# Calculating CSR at s= 0.7
# --- 4.538216829299927 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-wakes.h5
# Finish step 8 in 5.354575872421265 seconds
# Calculating CSR at s= 0.7999999999999999
# --- 4.549744367599487 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-wakes.h5
# Finish step 9 in 5.3377768993377686 seconds
# Calculating CSR at s= 0.8999999999999999
# --- 4.193429231643677 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-wakes.h5
# Finish step 10 in 4.957178831100464 seconds
# Calculating CSR at s= 0.9999999999999999
# --- 4.291369915008545 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-wakes.h5
# Finish step 11 in 5.056341171264648 seconds
# Calculating CSR at s= 1.0999999999999999
# --- 4.3842480182647705 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-wakes.h5
# Finish step 12 in 5.160167217254639 seconds
# Calculating CSR at s= 1.2
# --- 4.145419120788574 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-wakes.h5
# Finish step 13 in 4.888259172439575 seconds
# Calculating CSR at s= 1.3
# --- 4.287839651107788 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-wakes.h5
# Finish step 14 in 5.08206844329834 seconds
# Calculating CSR at s= 1.4000000000000001
# --- 4.122815847396851 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-wakes.h5
# Finish step 15 in 4.883702278137207 seconds
# Calculating CSR at s= 1.5000000000000002
# --- 4.1293652057647705 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-wakes.h5
# Finish step 16 in 4.933448314666748 seconds
# Statistics written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/dipole_fromfile-2024-05-27T15_38_49-07_00-statistics.h5

# %% [markdown]
# ## Parallel Run with MPI

# %%
# input yaml file in "./input/dipole_config.yaml"
# !mpirun -n 4 python  -m pyDFCSR_mpi_run ./input/chicane_config.yaml
# Out:
# 'mpirun' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## Plot output

# %%
from plot_from_output import DFCSR_postprocessor

DFplot = DFCSR_postprocessor(run_name = 'dipole_fromfile-2024-05-27T15_38_49-07_00',
                             work_dir = './output')

# %%
# Plot beam size along the lattice
DFplot.plot_stats(key = 'sigZ')

# %%
DFplot.plot_wakes(s = 0.6)
# Out:
# plot longitudinal wakes at nearest point s  = 0.6 m, step count 6
# ebeam energy 5000000000.0

# %%
DFplot.plot_particles(s = 0.6, xkey = 'z', ykey = 'x')
# Out:
# plot longitudinal wakes at nearest point s  = 0.6 m, step count 6

# %%
DFplot.plot_stats(key = 'gemitX_minus_dispersion')
