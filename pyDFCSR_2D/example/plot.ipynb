# %%
# %matplotlib widget 
import sys
sys.path.insert(0,'../')
from plot_from_output import DFCSR_postprocessor

# %%
DFplot = DFCSR_postprocessor(run_name = 'chicane-2024-06-05T01_45_25-07_00',
                             work_dir = '/sdf/data/ad/ard/u/jytang/pyDFCSR/chicane_output/')

DFplot.plot_wakes(s = 12.7)
# Out:
# plot longitudinal wakes at nearest point s  = 12.69999999999997 m, step count 127
# ebeam energy 5000000026.212385
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
DFplot.plot_stats('slope')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 DFplot.plot_stats('slope')
#
# File /sdf/group/ad/beamphysics/jytang/pyDFCSR/pyDFCSR_2D/example/../plot_from_output.py:225, in DFCSR_postprocessor.plot_stats(self, key)
#     223 def plot_stats(self, key='sigZ'):
# --> 225     with h5py.File(self.statistics_filename, "r") as f:
#     226         x = np.array(f['step_positions'])
#     227         y = np.array(f[key])
#
# File ~/miniconda3/envs/pyDFCSR/lib/python3.8/site-packages/h5py/_hl/files.py:562, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
# ...

# %% [markdown]
# ##### Plot beam size along the lattice

# %%
DFplot.plot_stats(key = 'sigX')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
DFplot.plot_stats(key = 'gemitX_minus_dispersion')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
DFplot.plot_particles(s = 7.5, xkey = 'z', ykey = 'x')
# Out:
# plot longitudinal wakes at nearest point s  = 7.499999999999989 m, step count 75
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
DFplot.plot_particles(s = 12.6, xkey = 'z', ykey = 'x')
# Out:
# plot longitudinal wakes at nearest point s  = 12.599999999999971 m, step count 126
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
DFplot.plot_particles(s = 11, xkey = 'z', ykey = 'x')
# Out:
# plot longitudinal wakes at nearest point s  = 11.099999999999977 m, step count 111
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
DFplot.plot_particles(s = 7.5, xkey = 'z', ykey = 'x')
# Out:
# plot longitudinal wakes at nearest point s  = 7.499999999999989 m, step count 75
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
