# %%
# %matplotlib widget 
import sys
sys.path.insert(0,'../')
import numpy as np
from CSR import *
import matplotlib.pyplot as plt
from matplotlib import cm
import h5py
from tools import plot_surface

# %% [markdown]
# ## Run DFCSR

# %%
testCSR = CSR2D(input_file= 'input/chicane_config.yaml')
# Out:
# start reinterpolation. number of slice 1

# %%
testCSR.run()
# Out:
# Starting the DFCSR run
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output\chicane-2024-06-17T00_00_42-07_00-wakes.h5
# Finish step 1, s = 0.1,  in 2.6183605194091797 seconds
# Finish step 2, s = 0.2,  in 2.895021438598633 seconds
# Finish step 3, s = 0.30000000000000004,  in 2.7367990016937256 seconds
# Finish step 4, s = 0.4,  in 2.813959836959839 seconds
# Finish step 5, s = 0.5,  in 2.7058417797088623 seconds
# Finish step 6, s = 0.6,  in 2.78098464012146 seconds
# start reinterpolation. number of slice 8
# Finish step 7, s = 0.7000000000000001,  in 3.809865713119507 seconds
# Finish step 8, s = 0.8,  in 0.5023078918457031 seconds
# Finish step 9, s = 0.9,  in 0.5261027812957764 seconds
# Finish step 10, s = 1.0,  in 0.5162167549133301 seconds
# Finish step 11, s = 1.1,  in 0.5399627685546875 seconds
# start reinterpolation. number of slice 13
# Finish step 12, s = 1.2000000000000002,  in 8.256524085998535 seconds
# Finish step 13, s = 1.3000000000000003,  in 0.9557654857635498 seconds
# Finish step 14, s = 1.4000000000000004,  in 0.8999345302581787 seconds
# Finish step 15, s = 1.5000000000000004,  in 0.934807300567627 seconds
# Finish step 16, s = 1.6000000000000005,  in 0.9354689121246338 seconds
# Beam at position 1.7000000000000006 is written to C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output\chicane-2024-06-17T00_00_42-07_00-particles-17.h5
# Finish step 17, s = 1.7000000000000006,  in 4.233380079269409 seconds
# Finish step 18, s = 1.8000000000000007,  in 0.9090490341186523 seconds
# Finish step 19, s = 1.9000000000000008,  in 0.9426279067993164 seconds
# Finish step 20, s = 2.000000000000001,  in 0.9338769912719727 seconds
# start reinterpolation. number of slice 14
# Finish step 21, s = 2.100000000000001,  in 4.7388293743133545 seconds
# Finish step 22, s = 2.200000000000001,  in 3.748605966567993 seconds
# Finish step 23, s = 2.300000000000001,  in 0.7498867511749268 seconds
# Finish step 24, s = 2.4000000000000012,  in 0.7468676567077637 seconds
# Finish step 25, s = 2.5000000000000013,  in 0.7526743412017822 seconds
# Finish step 26, s = 2.6000000000000014,  in 0.7789993286132812 seconds
# Finish step 27, s = 2.7000000000000015,  in 3.624466896057129 seconds
# Finish step 28, s = 2.8000000000000016,  in 0.8637034893035889 seconds
# Finish step 29, s = 2.9000000000000017,  in 0.8133354187011719 seconds
# Finish step 30, s = 3.0000000000000018,  in 0.7657694816589355 seconds
# Finish step 31, s = 3.100000000000002,  in 0.7526273727416992 seconds
# Beam at position 3.200000000000002 is written to C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output\chicane-2024-06-17T00_00_42-07_00-particles-32.h5
# Finish step 32, s = 3.200000000000002,  in 4.119873523712158 seconds
# Finish step 33, s = 3.300000000000002,  in 0.8011355400085449 seconds
# Finish step 34, s = 3.400000000000002,  in 0.8170719146728516 seconds
# Finish step 35, s = 3.500000000000002,  in 0.8128147125244141 seconds
# Finish step 36, s = 3.6000000000000023,  in 0.8006949424743652 seconds
# Finish step 37, s = 3.7000000000000024,  in 3.526282548904419 seconds
# Finish step 38, s = 3.8000000000000025,  in 0.7766799926757812 seconds
# start reinterpolation. number of slice 14
# Finish step 39, s = 3.9000000000000026,  in 2.2441458702087402 seconds
# Finish step 40, s = 4.000000000000003,  in 0.5444772243499756 seconds
# Finish step 41, s = 4.100000000000002,  in 0.5458388328552246 seconds
# Finish step 42, s = 4.200000000000002,  in 3.5840914249420166 seconds
# Finish step 43, s = 4.300000000000002,  in 0.7142834663391113 seconds
# Finish step 44, s = 4.400000000000001,  in 0.6090917587280273 seconds
# Finish step 45, s = 4.500000000000001,  in 0.5895919799804688 seconds
# Finish step 46, s = 4.6000000000000005,  in 0.566887378692627 seconds
# Beam at position 4.7 is written to C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output\chicane-2024-06-17T00_00_42-07_00-particles-47.h5
# Finish step 47, s = 4.7,  in 3.894516706466675 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 48, s = 4.8,  in 0.5328938961029053 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 49, s = 4.8999999999999995,  in 0.5593917369842529 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 50, s = 4.999999999999999,  in 0.5619363784790039 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 51, s = 5.099999999999999,  in 0.5463624000549316 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 52, s = 5.199999999999998,  in 0.537956714630127 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 53, s = 5.299999999999998,  in 0.5151591300964355 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 54, s = 5.399999999999998,  in 0.523479700088501 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 55, s = 5.499999999999997,  in 0.5020263195037842 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 56, s = 5.599999999999997,  in 0.5185754299163818 seconds
# Finish step 57, s = 5.7,  in 3.5118954181671143 seconds
# Finish step 58, s = 5.8,  in 3.7838926315307617 seconds
# Finish step 59, s = 5.8999999999999995,  in 3.443103790283203 seconds
# Finish step 60, s = 5.999999999999999,  in 3.4596476554870605 seconds
# Finish step 61, s = 6.099999999999999,  in 3.3275363445281982 seconds
# Finish step 62, s = 6.2,  in 3.1897499561309814 seconds
# Finish step 63, s = 6.3,  in 3.1198642253875732 seconds
# Finish step 64, s = 6.3999999999999995,  in 3.101884603500366 seconds
# Finish step 65, s = 6.499999999999999,  in 3.1151678562164307 seconds
# Finish step 66, s = 6.599999999999999,  in 3.1377761363983154 seconds
# Finish step 67, s = 6.699999999999998,  in 3.0795910358428955 seconds
# Finish step 68, s = 6.799999999999998,  in 3.204646348953247 seconds
# Finish step 69, s = 6.899999999999998,  in 3.166440963745117 seconds
# Finish step 70, s = 6.999999999999997,  in 3.0830204486846924 seconds
# Finish step 71, s = 7.099999999999997,  in 3.1652677059173584 seconds
# start reinterpolation. number of slice 12
# Finish step 72, s = 7.2,  in 4.509441614151001 seconds
# Finish step 73, s = 7.3,  in 3.4599902629852295 seconds
# Finish step 74, s = 7.3999999999999995,  in 3.5586044788360596 seconds
# start reinterpolation. number of slice 12
# Finish step 75, s = 7.499999999999999,  in 6.255088806152344 seconds
# start reinterpolation. number of slice 12
# Finish step 76, s = 7.599999999999999,  in 9.017386436462402 seconds
# start reinterpolation. number of slice 7
# Finish step 77, s = 7.7,  in 9.722174167633057 seconds
# start reinterpolation. number of slice 7
# Finish step 78, s = 7.8,  in 3.1534526348114014 seconds
# start reinterpolation. number of slice 7
# Finish step 79, s = 7.8999999999999995,  in 2.5766286849975586 seconds
# start reinterpolation. number of slice 7
# Finish step 80, s = 7.999999999999999,  in 2.1619913578033447 seconds
# start reinterpolation. number of slice 7
# Finish step 81, s = 8.1,  in 1.5425620079040527 seconds
# Finish step 82, s = 8.2,  in 3.356215476989746 seconds
# Finish step 83, s = 8.299999999999999,  in 0.50787353515625 seconds
# Finish step 84, s = 8.399999999999999,  in 0.5122730731964111 seconds
# Finish step 85, s = 8.499999999999998,  in 0.5340573787689209 seconds
# Finish step 86, s = 8.599999999999998,  in 0.5435848236083984 seconds
# Finish step 87, s = 8.699999999999998,  in 3.4438984394073486 seconds
# Finish step 88, s = 8.799999999999997,  in 0.501652717590332 seconds
# Finish step 89, s = 8.899999999999997,  in 0.5024099349975586 seconds
# Finish step 90, s = 8.999999999999996,  in 0.5236904621124268 seconds
# Finish step 91, s = 9.099999999999996,  in 0.51568603515625 seconds
# Finish step 92, s = 9.199999999999996,  in 3.4374845027923584 seconds
# Finish step 93, s = 9.299999999999995,  in 0.5117876529693604 seconds
# Finish step 94, s = 9.399999999999995,  in 0.515009880065918 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 95, s = 9.499999999999995,  in 0.5167999267578125 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 96, s = 9.599999999999994,  in 0.5199642181396484 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 97, s = 9.699999999999994,  in 0.5295934677124023 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 98, s = 9.799999999999994,  in 0.5929796695709229 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 99, s = 9.899999999999993,  in 0.5811154842376709 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 100, s = 9.999999999999993,  in 0.5202577114105225 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 101, s = 10.099999999999993,  in 0.5255863666534424 seconds
# start reinterpolation. number of slice 7
# Far away from a bending magnet, stopping calculating CSR
# Finish step 102, s = 10.199999999999992,  in 1.0161981582641602 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 103, s = 10.299999999999992,  in 0.4431021213531494 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 104, s = 10.399999999999991,  in 0.4398989677429199 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 105, s = 10.499999999999991,  in 0.4121377468109131 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 106, s = 10.59999999999999,  in 0.4335792064666748 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 107, s = 10.69999999999999,  in 0.4565086364746094 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 108, s = 10.79999999999999,  in 0.4816858768463135 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 109, s = 10.89999999999999,  in 0.5161540508270264 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 110, s = 10.99999999999999,  in 0.4518139362335205 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 111, s = 11.099999999999989,  in 0.4570634365081787 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 112, s = 11.199999999999989,  in 0.4959688186645508 seconds
# start reinterpolation. number of slice 7
# Far away from a bending magnet, stopping calculating CSR
# Finish step 113, s = 11.299999999999988,  in 1.1827402114868164 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 114, s = 11.399999999999988,  in 0.4535834789276123 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 115, s = 11.499999999999988,  in 0.4781014919281006 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 116, s = 11.599999999999987,  in 0.4942796230316162 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 117, s = 11.699999999999987,  in 0.46883201599121094 seconds
# start reinterpolation. number of slice 7
# Far away from a bending magnet, stopping calculating CSR
# Finish step 118, s = 11.799999999999986,  in 1.4067988395690918 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 119, s = 11.899999999999986,  in 0.4962952136993408 seconds
# Far away from a bending magnet, stopping calculating CSR
# Finish step 120, s = 11.999999999999986,  in 0.49828052520751953 seconds
# start reinterpolation. number of slice 7
# Far away from a bending magnet, stopping calculating CSR
# Finish step 121, s = 12.099999999999985,  in 1.3561186790466309 seconds
# start reinterpolation. number of slice 7
# Far away from a bending magnet, stopping calculating CSR
# Finish step 122, s = 12.199999999999985,  in 1.4298973083496094 seconds
# start reinterpolation. number of slice 7
# Far away from a bending magnet, stopping calculating CSR
# Finish step 123, s = 12.299999999999985,  in 1.575826644897461 seconds
# start reinterpolation. number of slice 7
# Far away from a bending magnet, stopping calculating CSR
# Finish step 124, s = 12.399999999999984,  in 1.6092770099639893 seconds
# start reinterpolation. number of slice 7
# Far away from a bending magnet, stopping calculating CSR
# Finish step 125, s = 12.499999999999984,  in 1.77180814743042 seconds
# start reinterpolation. number of slice 7
# Far away from a bending magnet, stopping calculating CSR
# Finish step 126, s = 12.599999999999984,  in 2.1177186965942383 seconds
# start reinterpolation. number of slice 7
# Finish step 127, s = 12.700000000000001,  in 6.213745355606079 seconds
# start reinterpolation. number of slice 7
# Finish step 128, s = 12.8,  in 6.962507247924805 seconds
# start reinterpolation. number of slice 7
# Finish step 129, s = 12.9,  in 7.411056995391846 seconds
# start reinterpolation. number of slice 7

# %% [markdown]
# ## Parallel Run with MPI

# %%
import pyDFCSR_mpi_run

# %%
# input yaml file in "./input/dipole_config.yaml"
#salloc --partition milano --account ad:beamphysics -N 1 -n 10 /usr/lib64/openmpi/bin/mpirun python  -m pyDFCSR_mpi_run ./input/dipole_config.yaml
# !mpirun -n 4 python  -m pyDFCSR_mpi_run.py ./input/chicane_config.yaml
# Out:
# /sdf/home/j/jytang/miniconda3/envs/pyDFCSR/bin/python: Error while finding module specification for 'pyDFCSR_mpi_run.py' (ModuleNotFoundError: No module named 'pyDFCSR_mpi_run')
# /sdf/home/j/jytang/miniconda3/envs/pyDFCSR/bin/python: Error while finding module specification for 'pyDFCSR_mpi_run.py' (ModuleNotFoundError: No module named 'pyDFCSR_mpi_run')
# /sdf/home/j/jytang/miniconda3/envs/pyDFCSR/bin/python: Error while finding module specification for 'pyDFCSR_mpi_run.py' (ModuleNotFoundError: No module named 'pyDFCSR_mpi_run')
# /sdf/home/j/jytang/miniconda3/envs/pyDFCSR/bin/python: Error while finding module specification for 'pyDFCSR_mpi_run.py' (ModuleNotFoundError: No module named 'pyDFCSR_mpi_run')

# %% [markdown]
# ## Plot output

# %%
from postprocessor import DFCSR_postprocessor

DFplot = DFCSR_postprocessor(run_name = 'chicane-2024-06-16T22_32_18-07_00',
                             work_dir = './output')

# %%
# Plot beam size along the lattice
x, y = DFplot.get_statistics(key = 'norm_emit_x', show_plot = True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x_grids, z_grids, xkicks, dE_dct = DFplot.get_wakes(s =7.5, show_plot = True)
# Out:
# plot longitudinal wakes at nearest point s  = 7.499999999999999 m, step count 75
# ebeam energy 5000000026.315029
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from pmd_beamphysics.plot import density_and_slice_plot
pg  = DFplot.get_particles()
pg.plot('x', 'px')
# Out:
# Reading  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chicane-2024-06-16T22_32_18-07_00-particles-end.h5
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
