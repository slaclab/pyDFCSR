# %%
import sys
sys.path.insert(0,'../')
import numpy as np

from CSR import *
import matplotlib.pyplot as plt
from matplotlib import cm
import h5py
from tools import plot_surface

# %% [markdown]
# ## Run DFCSR

# %%
testCSR = CSR2D(input_file= 'input/dipole_config.yaml')

# %%
testCSR.run()
# Out:
# Calculating CSR at s= 0.1
# --- 4.879157066345215 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-wakes.h5
# Finish step 2 in 5.688544034957886 seconds
# Calculating CSR at s= 0.2
# --- 4.381191730499268 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-wakes.h5
# Finish step 3 in 5.154332399368286 seconds
# Calculating CSR at s= 0.30000000000000004
# --- 4.439939975738525 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-wakes.h5
# Finish step 4 in 5.280196189880371 seconds
# Calculating CSR at s= 0.4
# --- 4.4340221881866455 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-wakes.h5
# Finish step 5 in 5.305136680603027 seconds
# Calculating CSR at s= 0.5
# --- 4.3726806640625 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-wakes.h5
# Finish step 6 in 5.26563835144043 seconds
# Calculating CSR at s= 0.6
# --- 4.2591283321380615 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-wakes.h5
# Finish step 7 in 5.026151418685913 seconds
# Calculating CSR at s= 0.7
# --- 4.2891528606414795 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-wakes.h5
# Finish step 8 in 5.178790807723999 seconds
# Calculating CSR at s= 0.7999999999999999
# --- 4.166746139526367 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-wakes.h5
# Finish step 9 in 5.043622255325317 seconds
# Calculating CSR at s= 0.8999999999999999
# --- 4.49884819984436 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-wakes.h5
# Finish step 10 in 5.385024547576904 seconds
# Calculating CSR at s= 0.9999999999999999
# --- 5.05109715461731 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-wakes.h5
# Finish step 11 in 5.927737712860107 seconds
# Calculating CSR at s= 1.0999999999999999
# --- 4.142210960388184 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-wakes.h5
# Finish step 12 in 4.957219362258911 seconds
# Calculating CSR at s= 1.2
# --- 4.217003345489502 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-wakes.h5
# Finish step 13 in 5.112012624740601 seconds
# Calculating CSR at s= 1.3
# --- 3.9377782344818115 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-wakes.h5
# Finish step 14 in 4.749907493591309 seconds
# Calculating CSR at s= 1.4000000000000001
# --- 3.9546523094177246 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-wakes.h5
# Finish step 15 in 4.811770915985107 seconds
# Calculating CSR at s= 1.5000000000000002
# --- 4.289581060409546 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-wakes.h5
# Finish step 16 in 5.205285549163818 seconds
# Calculating CSR at s= 1.6000000000000003
# --- 4.552914619445801 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-wakes.h5
# Finish step 17 in 5.482832431793213 seconds
# Calculating CSR at s= 1.7000000000000004
# --- 4.3535850048065186 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-wakes.h5
# Finish step 18 in 5.269413232803345 seconds
# Calculating CSR at s= 1.8000000000000005
# --- 4.434430360794067 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-wakes.h5
# Finish step 19 in 5.366128206253052 seconds
# Calculating CSR at s= 1.9000000000000006
# --- 4.43999719619751 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-wakes.h5
# Finish step 20 in 5.312769412994385 seconds
# Calculating CSR at s= 2.0000000000000004
# --- 4.79802680015564 seconds ---
# Beams written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-particles.h5
# Wakes written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-wakes.h5
# Finish step 21 in 5.67651891708374 seconds
# Statistics written to  C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\example\output/chirp-2024-05-27T14_29_56-07_00-statistics.h5

# %% [markdown]
# ## Parallel Run with MPI

# %%
# input yaml file in "./input/dipole_config.yaml"
# !mpirun -n 4 python  -m pyDFCSR_mpi_run ./input/chicane_config.yaml
# Out:
# 'mpirun' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## Plot output

# %%
from plot_from_output import DFCSR_postprocessor

DFplot = DFCSR_postprocessor(run_name = 'chirp-2024-05-27T14_29_56-07_00',
                             work_dir = './output')

# %%
# Plot beam size along the lattice
DFplot.plot_stats(key = 'sigZ')

# %%
DFplot.plot_wakes(s = 2.0)
# Out:
# plot longitudinal wakes at nearest point s  = 2.0000000000000004 m, step count 20
# ebeam energy 5000000026.236993

# %%
DFplot.plot_particles(s = 0.6, xkey = 'z', ykey = 'x')
# Out:
# plot longitudinal wakes at nearest point s  = 0.5499999999999999 m, step count 11

# %%
DFplot.plot_stats(key = 'gemitX_minus_dispersion')
