# %%
# %matplotlib widget 
import sys
sys.path.insert(0,'../')
from plot_from_output import DFCSR_postprocessor

# %%
DFplot = DFCSR_postprocessor(run_name = 'chicane-2024-05-28T14_25_31-07_00',
                             work_dir = '/sdf/data/ad/ard/u/jytang/pyDFCSR/chicane_output/')

DFplot.plot_wakes(s = 12.9)
# Out:
# plot longitudinal wakes at nearest point s  = 12.89999999999997 m, step count 129
# ebeam energy 5000000026.255665
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
DFplot.plot_stats('slope')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ##### Plot beam size along the lattice

# %%
DFplot.plot_stats(key = 'sigZ')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
DFplot.plot_stats(key = 'gemitX_minus_dispersion')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
