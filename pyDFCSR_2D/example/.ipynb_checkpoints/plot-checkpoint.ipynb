# %%
# %matplotlib widget 
from plot_from_output import DFCSR_postprocessor

# %%
DFplot = DFCSR_postprocessor(run_name = 'facet_obed-2024-05-27T09_30_01-07_00',
                             work_dir = './output/')

DFplot.plot_wakes(s = 0.65)
# Out:
# plot longitudinal wakes at nearest point s  = 0.65 m, step count 13
# ebeam energy 9856000000.0
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
DFplot.plot_stats('slope')
# Out:
# C:\Users\yingb\Desktop\pyDFCSR\pyDFCSR_2D\plot_from_output.py:206: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ##### Plot beam size along the lattice

# %%
DFplot.plot_stats(key = 'sigZ')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
DFplot.plot_stats(key = 'gemitX_minus_dispersion')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
