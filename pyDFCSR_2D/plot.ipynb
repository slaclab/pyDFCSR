# %%
from plot_from_output import DFCSR_postprocessor

DFplot = DFCSR_postprocessor(run_name = '/chicane-2024-04-11T23_43_50-07_00',
                             work_dir = '/sdf/data/ad/ard/u/jytang/pyDFCSR/chicane_output')

# %%
# Plot beam size along the lattice
DFplot.plot_stats(key = 'sigZ')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Plot beam size along the lattice
# ----> 2 DFplot.plot_stats(key = 'sigZ')
#
# File /sdf/group/ad/beamphysics/jytang/pyDFCSR/pyDFCSR_2D/plot_from_output.py:183, in DFCSR_postprocessor.plot_stats(self, key)
#     181 def plot_stats(self, key='sigZ'):
# --> 183     with h5py.File(self.statistics_filename, "r") as f:
#     184         x = np.array(f['step_positions'])
#     185         y = np.array(f[key])
#
# File ~/miniconda3/envs/pyDFCSR/lib/python3.8/site-packages/h5py/_hl/files.py:562, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
# ...

# %%
DFplot.plot_wakes(s = 5.75)
# Out:
# plot longitudinal wakes at nearest point s  = 5.799999999999995 m, step count 58
# ebeam energy 5000000026.255665
