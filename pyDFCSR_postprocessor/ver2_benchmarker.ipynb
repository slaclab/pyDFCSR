# %%
from generate_data_ver2 import generate_data_ver2
wake_data, histo_data = generate_data_ver2("input/dipole_config_ver2.yaml", 13)
# Out:
# done with init
# 100%|██████████| 4/4 [00:09<00:00,  2.40s/it]

# %%
# %matplotlib widget
from plotter import plot_wakes, plot_histos
plot_wakes(wake_data)
plot_histos(histo_data)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
