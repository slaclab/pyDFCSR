# %%
from histogram_postprocessor import *

# %%
# Chicane, wakes not applied
new_histos_chicane = load_new_histo_data("/Users/treyfischbach/Desktop/Stuff/Research/SLAC 2024/Program Output/Benchmarking new code to old code/dipole_histograming/chicane density wake 3_histograms.h5")

# %%
# %matplotlib widget

# Plot the histograms of the beam in a specified step range
for i in range(25, 40):
    plot_histos(new_histos_chicane[i])
