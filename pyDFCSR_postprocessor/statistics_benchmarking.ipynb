# %%
from statistics_post_processor import *

# %%
# Chicane, 2D beam, initial slope zero
stats_2D_old = read_old_2D_stats("/Users/treyfischbach/Desktop/Stuff/Research/SLAC 2024/Program Output/Benchmarking new code to old code/chicane/chicane 2D beam-2024-10-04T12_03_49-05_00-statistics.h5")
stats_2D_new = read_new_2D_stats("/Users/treyfischbach/Desktop/Stuff/Research/SLAC 2024/Program Output/Benchmarking new code to old code/chicane/s0 wakes applied 2D chicane_stats.h5")

#stats_CSRtrack = read_CSRtrack_stats("/Users/treyfischbach/Desktop/Stuff/Research/SLAC 2024/Program Output/Presentation Benchmarking/for_Trey/out", 15)

#stats_2D_old_2 = read_old_2D_stats("/Users/treyfischbach/Desktop/Stuff/Research/SLAC 2024/Program Output/Presentation Benchmarking/chicane 2D beam-2024-09-06T12_20_49-05_00-statistics.h5")
#stats_2D_new_2 = read_new_2D_stats("/Users/treyfischbach/Desktop/Stuff/Research/SLAC 2024/Program Output/Presentation Benchmarking/s0 wakes applied 2D chicane_stats.h5")
#stats_3D = read_new_2D_stats("/Users/treyfischbach/Desktop/Stuff/Research/SLAC 2024/Program Output/Presentation Benchmarking/s0 beam wakes applied chicane_stats.h5")

# %%
stats = [stats_2D_old["twiss"]["emit_x"], stats_2D_new["twiss"]["emit_x"]]
labels = ["pyDFCSR_2D_old", "pyDFCSR_2D_new"]

plot_statistics(stats, labels, figure_title="emit_x for dipole 2D beam", axis_title="emit_x")
