# %%
from generate_data_ver1 import generate_data_ver1
wake_data, histo_data = generate_data_ver1("input/dipole_config_ver1.yaml", 13)
# Out:
# start reinterpolation. number of slice 1
# xbins = 500  zbins =  500
# Starting the DFCSR run
# Drift(L=0.1)
# Finish step 1, s = 0.1,  in 0.3887369632720947 seconds
# SBend(L=0.1, P0C=5000000026.236993, G=1.0, DG=0.0, E1=0, E2=0.0, FINT=0.0, HGAP=0.0, FINTX=0.0, HGAPX=0.0, FRINGE_AT='both_ends', FRINGE_TYPE='linear_edge', TILT=0.0)
# Finish step 2, s = 0.2,  in 0.7705080509185791 seconds
# SBend(L=0.1, P0C=5000000026.236993, G=1.0, DG=0.0, E1=0.0, E2=0.0, FINT=0.0, HGAP=0.0, FINTX=0.0, HGAPX=0.0, FRINGE_AT='both_ends', FRINGE_TYPE='linear_edge', TILT=0.0)
# start reinterpolation. number of slice 3
# xbins = 510  zbins =  1110
# Finish step 3, s = 0.30000000000000004,  in 1.1960933208465576 seconds
# SBend(L=0.1, P0C=5000000026.236993, G=1.0, DG=0.0, E1=0.0, E2=0.0, FINT=0.0, HGAP=0.0, FINTX=0.0, HGAPX=0.0, FRINGE_AT='both_ends', FRINGE_TYPE='linear_edge', TILT=0.0)
# start reinterpolation. number of slice 3
# xbins = 520  zbins =  1116
# ...

# %%
# Create a new HDF5 file
import h5py

# Define the filename
filename = 'old_data.h5'

# Create a new HDF5 file
with h5py.File(filename, 'w') as f:
    for key, value in histo_data.items():
        f.create_dataset(key, data=value)

# %%
# %matplotlib widget
from plotter import plot_wakes, plot_histos
plot_wakes(wake_data)
plot_histos(histo_data)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
