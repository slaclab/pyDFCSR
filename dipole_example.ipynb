# %%
# Import CSR2D
from csr2d import CSR2D

# %%
# %matplotlib widget

# Hi Jingyi! Thank you for taking a look at this!

# Create the CSR2D object with the input file
csr_2d = CSR2D(input_file= 'input/dipole_config.yaml')

# Run the simulation, parameters are not necessary, but will save time with chicane
csr_2d.run(stop_step=8, start_CSR_computations=2)

# Save the data to the desired location
csr_2d.save_data("/Users/treyfischbach/Desktop/Stuff/Research/SLAC 2024/Program Output/Benchmarking new code to old code/dipole_histograming", "density example")

# You also can plot the integrands
csr_2d = CSR2D(input_file= 'input/dipole_config.yaml')
csr_2d.run(plot_integrands=True, stop_step=8, start_CSR_computations=2)
# Out:
# CSR2D Object Succesfully Initialized
# 100%|██████████| 7/7 [00:41<00:00,  5.98s/it]
# CSR2D Object Succesfully Initialized
#  14%|█▍        | 1/7 [00:00<00:02,  2.60it/s]
# for step 2 and area number 0 :
# 8.67e+08
# area of mesh
# 0.000353374373988602
# (200,)
# (100,)
#
# for step 2 and area number 1 :
# -1.25e+08
# area of mesh
# 2.449218723818017e-05
# (100,)
# (100,)
#
# for step 2 and area number 2 :
# -6.40e+09
# area of mesh
# 1.2692245271063617e-06
# (100,)
# (200,)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# for step 2 and area number 0 :
# 8.54e+08
# area of mesh
# 0.000353374373988602
# (200,)
# (100,)
#
# for step 2 and area number 1 :
# -9.23e+07
# area of mesh
# 2.449218723818017e-05
# (100,)
# (100,)
#
# for step 2 and area number 2 :
# -1.14e+08
# area of mesh
# 1.2692245271063617e-06
# (100,)
# (200,)
# ...
